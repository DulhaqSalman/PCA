# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\sath\Desktop\numpy notes\dataser_img\Boston.csv")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  CAT. MEDV  Unnamed: 15  Unnamed: 16
# 0  396.90   4.98  24.0          0          NaN          NaN
# 1  396.90   9.14  21.6          0          NaN          NaN
# 2  392.83   4.03  34.7          1          NaN          NaN
# 3  394.63   2.94  33.4          1          NaN          NaN
# 4  396.90   5.33  36.2          1          NaN          NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CRIM         506 non-null    float64
#  1   ZN           506 non-null    float64
#  2   INDUS        506 non-null    float64
#  3   CHAS         506 non-null    int64
#  4   NOX          506 non-null    float64
#  5   RM           506 non-null    float64
#  6   AGE          506 non-null    float64
#  7   DIS          506 non-null    float64
#  8   RAD          506 non-null    int64
#  9   TAX          506 non-null    int64
#  10  PTRATIO      506 non-null    float64
#  11  B            506 non-null    float64
#  12  LSTAT        506 non-null    float64
#  13  MEDV         506 non-null    float64
#  14  CAT. MEDV    506 non-null    int64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
# dtypes: float64(13), int64(4)
# memory usage: 67.3 KB

# %%
data.isnull().sum()
# Out:
# CRIM             0
# ZN               0
# INDUS            0
# CHAS             0
# NOX              0
# RM               0
# AGE              0
# DIS              0
# RAD              0
# TAX              0
# PTRATIO          0
# B                0
# LSTAT            0
# MEDV             0
# CAT. MEDV        0
# Unnamed: 15    506
# Unnamed: 16    506
# dtype: int64

# %%
data['CHAS'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['RAD'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24], dtype=int64)

# %%
data.drop(columns=['CHAS','RAD','Unnamed: 15','Unnamed: 16','CAT. MEDV'],inplace=True)

# %%
data
# Out:
#         CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO       B  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900  296     15.3  396.90
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671  242     17.8  396.90
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671  242     17.8  392.83
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622  222     18.7  394.63
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622  222     18.7  396.90
# ..       ...   ...    ...    ...    ...   ...     ...  ...      ...     ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786  273     21.0  391.99
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875  273     21.0  396.90
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675  273     21.0  396.90
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889  273     21.0  393.45
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050  273     21.0  396.90
#
#      LSTAT  MEDV
# 0     4.98  24.0
# 1     9.14  21.6
# ...

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
data_cov=data.cov()
data_cov
# Out:
#                CRIM           ZN       INDUS        NOX         RM  \
# CRIM      73.986578   -40.215956   23.992339   0.419594  -1.325038
# ZN       -40.215956   543.936814  -85.412648  -1.396148   5.112513
# INDUS     23.992339   -85.412648   47.064442   0.607074  -1.887957
# NOX        0.419594    -1.396148    0.607074   0.013428  -0.024603
# RM        -1.325038     5.112513   -1.887957  -0.024603   0.493671
# AGE       85.405322  -373.901548  124.513903   2.385927  -4.751929
# DIS       -6.876722    32.629304  -10.228097  -0.187696   0.303663
# TAX      844.821538 -1236.453735  833.360290  13.046286 -34.583448
# PTRATIO    5.399331   -19.776571    5.692104   0.047397  -0.540763
# B       -302.381816   373.721402 -223.579756  -4.020570   8.215006
# LSTAT     27.986168   -68.783037   29.580270   0.488946  -3.079741
# MEDV     -30.718508    77.315176  -30.520823  -0.455412   4.493446
#
#                  AGE         DIS           TAX     PTRATIO            B  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data_sc=sc.fit_transform(data)

# %%
data_sc=pd.DataFrame(data_sc,columns=data.columns)

# %%
data_cov=data_sc.cov()
data_cov
# Out:
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.001980 -0.200866  0.407389  0.421805 -0.219681  0.353433 -0.380422
# ZN      -0.200866  1.001980 -0.534885 -0.517627  0.312608 -0.570665  0.665724
# INDUS    0.407389 -0.534885  1.001980  0.765164 -0.392451  0.646055 -0.709429
# NOX      0.421805 -0.517627  0.765164  1.001980 -0.302787  0.732919 -0.770753
# RM      -0.219681  0.312608 -0.392451 -0.302787  1.001980 -0.240741  0.205653
# AGE      0.353433 -0.570665  0.646055  0.732919 -0.240741  1.001980 -0.749361
# DIS     -0.380422  0.665724 -0.709429 -0.770753  0.205653 -0.749361  1.001980
# TAX      0.583918 -0.315186  0.722187  0.669346 -0.292626  0.507458 -0.535490
# PTRATIO  0.290520 -0.392454  0.384006  0.189307 -0.356205  0.262033 -0.232931
# B       -0.385826  0.175868 -0.357683 -0.380803  0.128322 -0.274076  0.292089
# LSTAT    0.456524 -0.413812  0.604995  0.592049 -0.615024  0.603531 -0.497980
# ...

# %%
eig_val,eig_vec=np.linalg.eig(data_cov)

# %%
eig_val
# Out:
# array([5.99985737, 1.52039042, 1.13885005, 0.81295663, 0.64502233,
#        0.52378472, 0.40218592, 0.13624558, 0.25604039, 0.21452902,
#        0.19123157, 0.1826684 ])

# %%
eig_vec
# Out:
# array([[-0.24232093, -0.05302587,  0.49179677, -0.1134701 , -0.41977424,
#          0.6543155 ,  0.1810462 , -0.09828088, -0.01066828, -0.01317512,
#          0.19122895,  0.00986604],
#        [ 0.26701504, -0.16344002,  0.44868707,  0.2559609 , -0.3444105 ,
#         -0.3752212 , -0.32866815,  0.13172868, -0.34653059, -0.06681312,
#          0.18924718, -0.30001264],
#        [-0.34910906,  0.13120742, -0.02692775, -0.0228234 , -0.09764353,
#         -0.41832169,  0.24063335, -0.07492774,  0.03766702,  0.44374813,
#          0.62537072,  0.14898271],
#        [-0.34069411,  0.27487068,  0.00833343,  0.20881507, -0.09075296,
#         -0.20267383,  0.05655179, -0.53151574,  0.23425067, -0.43353524,
#         -0.0803645 , -0.42473044],
#        [ 0.22368362,  0.49737227,  0.27634001, -0.31496836,  0.05056169,
#          0.02448437, -0.42704588,  0.04495322,  0.49848065,  0.26375338,
#          0.03176223, -0.14288109],
# ...

# %%
eig_val1=list(eig_val)
eig_val1.sort(reverse=True)
eig_val1
# Out:
# [5.9998573676825915,
#  1.5203904155657817,
#  1.1388500543903914,
#  0.8129566302405806,
#  0.6450223262478458,
#  0.523784715305208,
#  0.40218592052567687,
#  0.2560403864741993,
#  0.21452901942193234,
#  0.19123156776565806,
#  0.18266839759159104,
#  0.1362455750261775]

# %%
plt.plot(eig_val1)
plt.plot(eig_val, 'bp')

# %%
eig_vec1=eig_vec[:,0:3]
eig_vec1
# Out:
# array([[-0.24232093, -0.05302587,  0.49179677],
#        [ 0.26701504, -0.16344002,  0.44868707],
#        [-0.34910906,  0.13120742, -0.02692775],
#        [-0.34069411,  0.27487068,  0.00833343],
#        [ 0.22368362,  0.49737227,  0.27634001],
#        [-0.31746235,  0.28495887, -0.16456086],
#        [ 0.31640818, -0.39914453,  0.15096001],
#        [-0.32103465,  0.02117044,  0.32846864],
#        [-0.21299277, -0.3366515 , -0.0853345 ],
#        [ 0.20024949,  0.00119585, -0.55664204],
#        [-0.33231538, -0.22378183, -0.04264545],
#        [ 0.28660172,  0.47533892,  0.05427398]])

# %%
print(data_sc.shape)
print(eig_vec1.shape)
# Out:
# (506, 12)
# (12, 3)

# %%
pc=data_sc.dot(eig_vec1)
print(pc)
pc.columns=['pc1','pc2','pc3']
pc
# Out:
#             0         1         2
# 0    1.867800  0.676853 -0.175369
# 1    1.137835 -0.057020 -0.865358
# 2    2.219974  1.141931 -0.327648
# 3    2.742817  0.351190 -0.301113
# 4    2.675430  0.611579 -0.301111
# ..        ...       ...       ...
# 501 -0.010405  0.307985 -0.962717
# 502 -0.293073  0.011653 -1.245187
# 503  0.062969  1.064413 -0.959538
# 504 -0.049884  0.751224 -0.997747
# 505 -0.550866 -0.464305 -1.333099
#
# [506 rows x 3 columns]
#           pc1       pc2       pc3
# 0    1.867800  0.676853 -0.175369
# 1    1.137835 -0.057020 -0.865358
# 2    2.219974  1.141931 -0.327648
# 3    2.742817  0.351190 -0.301113
# 4    2.675430  0.611579 -0.301111
# ..        ...       ...       ...
# 501 -0.010405  0.307985 -0.962717
# 502 -0.293073  0.011653 -1.245187
# 503  0.062969  1.064413 -0.959538
# 504 -0.049884  0.751224 -0.997747
# 505 -0.550866 -0.464305 -1.333099
#
# [506 rows x 3 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=3,random_state=0)
pca1=pca.fit_transform(data_sc)
pca1
# Out:
# array([[-1.86780019,  0.67685265, -0.17536925],
#        [-1.13783533, -0.05701963, -0.86535816],
#        [-2.21997449,  1.14193055, -0.32764775],
#        ...,
#        [-0.06296897,  1.0644134 , -0.9595381 ],
#        [ 0.04988436,  0.75122366, -0.99774743],
#        [ 0.55086575, -0.46430492, -1.33309905]])

# %%
pca2=pd.DataFrame(pca1,columns=["pc1",'pc2','pc3'])
pca2
# Out:
#           pc1       pc2       pc3
# 0   -1.867800  0.676853 -0.175369
# 1   -1.137835 -0.057020 -0.865358
# 2   -2.219974  1.141931 -0.327648
# 3   -2.742817  0.351190 -0.301113
# 4   -2.675430  0.611579 -0.301111
# ..        ...       ...       ...
# 501  0.010405  0.307985 -0.962717
# 502  0.293073  0.011653 -1.245187
# 503 -0.062969  1.064413 -0.959538
# 504  0.049884  0.751224 -0.997747
# 505  0.550866 -0.464305 -1.333099
#
# [506 rows x 3 columns]

# %%
print("Total explained variance",sum(pca.explained_variance_ratio_))
pca.explained_variance_ratio_
# Out:
# Total explained variance 0.7201654163385329
# array([0.499     , 0.12644881, 0.09471661])

# %%
print("Total explained variance",sum(pc.explained_variance_ratio_))
pc.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3928/875375861.py in <module>
# ----> 1 print("Total explained variance",sum(pc.explained_variance_ratio_))
#       2 pc.explained_variance_ratio_
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'explained_variance_ratio_'
